# %% [markdown]
# # Translator Use Case SARS (as COVID-19 proxy)

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Translator Use Case Question #2 is:
#
# > What genes or proteins may be associated with symptoms of a disease X (such as based on drugs that are currently used to treat that disease, etc)?
#
# <br>
#
# BioThings Explorer (BTE) can answer two classes of queries -- "EXPLAIN" and "PREDICT". This Question fits the PREDICT  template of starting with **a specific biomedical entity** (a specific `Disease` X) and finding relationships with **one biomedical entity type** (like `PhenotypicFeature` or `Gene`).
# * Note that currently a `Protein` biomedical entity type is not implemented in BTE. Instead, protein-coding and some non-coding gene information is implemented as the `Gene` type.
#
# <br>
#
# We will use severe acute respiratory syndrome (SARS), as a proxy for COVID-19, as our specific disease of interest. We address the question above using the query: `Disease` SARS &rarr; `PhenotypicFeature` &rarr; `Gene`.
# * In other words, starting with the Disease SARS, find entities of type PhenotypicFeature associated with this disease, then find the entities of type Gene associated with those PhenotypicFeatures.
# * This query will return a graph object with entities as nodes and relationships as edges. We then use edge provenance information to **filter** the results. For each Gene node, we use the number of unique paths from SARS (input node) to that node to **score** it. The scores can then be used to sort the results.

# %% [markdown]
# ## Step 0: Load BTE modules, notebook functions

# %%
## CX: allows multiple lines of code to print from one code block
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# import modules from biothings_explorer
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

## show time that this notebook was executed 
from datetime import datetime

## packages to work with objects 
import re

# %%
## functions to add to modules?
def hint_display(query, hint_result):
    """
    show the name and type of all results returned by the query
    
    :param: query: string used in hint query
    :param: hint_result: object returned from hint query, a dictionary of lists of dictionaries
    
    Returns: None
    """
    ## function needs to be rewritten if it's going to give the exact index of each object within its type 
    display = ['type', 'name']  ## replace with the parts of the BioThings object you want to see
    concise_results = []
    for BT_type, result in hint_result.items():
        if result:  ## basically if it's not empty
            for items in result:
                concise_results.append((items[display[0]], items[display[1]]))
    print('There are {total} BioThings objects returned for {ht}:'.format(\
                total = len(concise_results), ht = query))
    for display_info in concise_results:
        print(display_info)

# %%
def filter_table(df):
    """
    use _source and _method columns to remove rows (paths) from the dataframe
    :param: pandas dataframe containing results from BTE FindConnection module, in table form
    
    Returns: filtered dataframe
    """
    ## note: still needs checking with EXPLAIN queries
    ## key is the string to match to column, value is a list of strings to match to column values
    filter_out = {'_source': ['SEMMED', 'CTD', 'ctd', 'omia']   
#                   '_method': []  ## currently no method stuff I want to filter out
                 }
    ## SEMMED: text mining results wrong for PhenotypicFeature -> Gene
    ## CTD/ctd: results odd for MSUD -> ChemicalSubstance
    ## omia: results wrong or discontinued gene IDs for PhenotypicFeature -> Gene
    
    
    df_temp = df.copy()  ## so the original df isn't modified in-place
    for key,val in filter_out.items():
        ## find columns that match the key string
        columns = [i for i in df_temp.columns if key in i]
        ## iterate through each column
        for col in columns:
            ## iterate through each value to take out, check if string CONTAINS match. 
            ## only keep rows that don't contain the value
            for i in val:
                df_temp = df_temp[~ df_temp[col].str.contains(i)]

    return df_temp

# %%
def scoring_output(df, q_type):
    """
    score based on flattened edges, equal to number of unique paths between input and output
        node(s) divided by the maximum number of paths possible between those node types
    :param: pandas dataframe containing results from BTE FindConnection module, in table form
    :param: string describing type of query (Predict or Explain)
    
    Returns: pandas series with scores, index is output_name
    """
    ## note: still needs code to work with EXPLAIN queries
    df_temp = df.copy()
    
    ## equivalent of flattening edges, remove edge provenance and remove duplicate rows
    columns_to_drop = [col for col in df_temp.columns if 'pred' in col]
    df_temp.drop(columns = columns_to_drop, inplace = True)
    df_temp.drop_duplicates(inplace = True)
    
    if q_type == "Predict":
        scores = df_temp.output_name.value_counts()

        ## figure out the other node layers, besides the output nodes
        ## currently the column with input node name is named "input" only. 
        ## other node name columns have _name suffixes
        temp_list = []
        for col in df_temp.columns:
            if col != 'output_name':
                if ('_name' in col) or (col == 'input'):
                    temp_list.append(col)    

        ## calculate maximum number of paths to output, using other node layers
        max_paths = 1
        for col in temp_list:
            max_paths *= df_temp[col].nunique()

        ## normalize scores by dividing each by max number of paths
        scores = scores / max_paths

        ## return scores as pandas dataframe
        return scores.to_frame(name = 'score')

# %%
## record when cell blocks are executed
print('The time that this notebook was executed is...')
print('Local time (PST, West Coast USA): ')
print(datetime.now())
print('UTC time: ')
print(datetime.utcnow())
# Out:
# The time that this notebook was executed is...
# Local time (PST, West Coast USA):
# 2020-09-04 16:15:57.848837
# UTC time:
# 2020-09-04 23:15:57.848993

# %% [markdown]
# ## Step 1: Find representation of "coronavirus" in BTE

# %% [markdown]
# In this step, BioThings Explorer translates our query string "coronavirus"  into BioThings objects, which contain mappings to many common identifiers. We then pick the BioThings object that best matches what we want (the rare disease).
#
# Generally, the top result returned by the Hint module for your BioThings type of interest will match what you want, but you should confirm that using the identifiers shown.
#
#
# > BioThings types correspond to children and descendants of [BiologicalEntity](https://biolink.github.io/biolink-model/docs/BiologicalEntity.html) from the [Biolink Model](https://biolink.github.io/biolink-model/docs/), including `Disease` (e.g., "lupus"), `ChemicalSubstance` (e.g., "acetaminophen"), `Gene` (e.g., "CDK2"), `BiologicalProcess` (e.g., "T cell differentiation"), and `Pathway` (e.g., "Citric acid cycle"). **However, [only a subset of the Biolink BiologicalEntity children / descendants are currently implemented in BTE](https://smart-api.info/portal/translator/metakg)**. More biomedical object types will be available as more knowledge sources (APIs) are added to the system. **Note that the type `BiologicalEntity` means any BioThings type currently implemented in BTE will be accepted.**

# %%
ht = Hint()  ## neater way to call this BTE module

## the human user gives this input
corona_starting_str = "coronavirus"

corona_hint = ht.query(corona_starting_str)
## the object is a dictionary with keys = set strings, values = list of dictionaries. 
hint_display(corona_starting_str, corona_hint)
# Out:
# There are 6 BioThings objects returned for coronavirus:
# ('Gene', 'human coronavirus sensitivity')
# ('ChemicalSubstance', 'AZD1222')
# ('Disease', 'COVID-19')
# ('Disease', 'severe acute respiratory syndrome')
# ('Disease', 'Orthocoronavirinae infectious disease')
# ('PhenotypicFeature', 'Susceptibility to coronavirus 229e')

# %% [markdown]
# Note: the query failed to retrieve Disease &rarr; PhenotypicFeatures for COVID-19 (sibling of SARS in Mondo) and Orthocoronavirinae infectious disease (parent of COVID-19 and SARS).
#
# So we'll pick the SARS `Disease` choice (indexed at 1) for our query. We can look at identifier mappings inside this BioThings object.

# %%
## the human user makes this choice, gives this input
corona_choice_type = 'Disease'
corona_choice_idx = 1

corona_hint_obj = corona_hint[corona_choice_type][corona_choice_idx]  
corona_hint_obj
## these inner dictionaries are keys = id type, 
##       values = curie, normal string, or dictionary (for the key 'primary')
# Out:
# {'MONDO': 'MONDO:0005091',
#  'DOID': 'DOID:2945',
#  'UMLS': 'C1175175',
#  'name': 'severe acute respiratory syndrome',
#  'MESH': 'D045169',
#  'ORPHANET': '140896',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0005091'},
#  'display': 'MONDO(MONDO:0005091) DOID(DOID:2945) ORPHANET(140896) UMLS(C1175175) MESH(D045169) name(severe acute respiratory syndrome)',
#  'type': 'Disease'}

# %% [markdown]
# ## Step 2: SARS &rarr; PhenotypicFeature &rarr; Gene

# %% [markdown]
# [edit this]
#
# In this section, we dynamically generate a knowledge graph with paths connecting SARS to genes *using PhenotypicFeature intermediates* (representing the symptoms part of the question).
#
# BTE performs the **query path planning** and **query path execution** by deconstructing the query into individual API calls, executing those API calls, and then assembling the results.
#
# The code block below takes about 1 minute to run.
# Ran: 21:35:05 2020-09-06 local time (PST)

# %%
## the human user gives this input
q1_output_type = 'Gene'
q1_intermediate = 'PhenotypicFeature'

q1 = FindConnection(input_obj = corona_hint_obj,\
                     output_obj = q1_output_type, \
                    intermediate_nodes = q1_intermediate)
q1.connect(verbose = True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'severe acute respiratory syndrome' and 'Gene'.                   Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: PhenotypicFeature
#
#
#
# ========== QUERY #1 -- fetch all PhenotypicFeature entities linked to severe acute respiratory syndrome ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because severe acute respiratory syndrome is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'PhenotypicFeature' as output
#
# BTE found 3 apis:
#
# API 1. biolink(1 API call)
# API 2. semmed_disease(11 API calls)
# API 3. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: https://mydisease.info/v1/query?fields=hpo.phenotype_related_to_disease (POST -d q=140896&scopes=hpo.orphanet)
# API 2.1: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C1175175&scopes=umls)
# API 2.6: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C1175175&scopes=umls)
# API 2.5: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C1175175&scopes=umls)
# API 2.9: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C1175175&scopes=umls)
# API 2.10: https://biothings.ncats.io/semmed/query?fields=disrupts (POST -d q=C1175175&scopes=umls)
# API 2.7: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C1175175&scopes=umls)
# API 2.2: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C1175175&scopes=umls)
# API 2.4: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C1175175&scopes=umls)
# API 2.11: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C1175175&scopes=umls)
# API 2.8: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C1175175&scopes=umls)
# API 2.3: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C1175175&scopes=umls)
# API 1.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0005091/phenotypes?rows=200&direct=true
#
#
# ==== Step #3: Output normalization ====
#
# API 2.1 semmed_disease: No hits
# API 2.2 semmed_disease: No hits
# API 2.3 semmed_disease: No hits
# API 2.4 semmed_disease: No hits
# API 1.1 biolink: 16 hits
# API 2.5 semmed_disease: No hits
# API 2.6 semmed_disease: No hits
# API 2.7 semmed_disease: No hits
# API 2.8 semmed_disease: No hits
# API 3.1 mydisease: 16 hits
# API 2.9 semmed_disease: No hits
# API 2.10 semmed_disease: No hits
# API 2.11 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 16 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all Gene entities linked to PhenotypicFeature entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'PhenotypicFeature', BTE will query our meta-KG for APIs that can take 'PhenotypicFeature' as input and 'Gene' as output
#
# BTE found 3 apis:
#
# API 1. biolink(32 API calls)
# API 2. ebi_gene2phenotype(1 API call)
# API 3. semmed_phenotype(13 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.22: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0012418/genes?rows=200
# API 3.12: https://biothings.ncats.io/semmedphenotype/query?fields=negatively_regulates (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.3: https://biothings.ncats.io/semmedphenotype/query?fields=related_to (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.13: https://biothings.ncats.io/semmedphenotype/query?fields=positively_regulated_by (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.5: https://biothings.ncats.io/semmedphenotype/query?fields=manifestation_of (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.2: https://biothings.ncats.io/semmedphenotype/query?fields=affected_by (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.6: https://biothings.ncats.io/semmedphenotype/query?fields=physically_interacts_with (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.9: https://biothings.ncats.io/semmedphenotype/query?fields=positively_regulates (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.11: https://biothings.ncats.io/semmedphenotype/query?fields=produces (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.7: https://biothings.ncats.io/semmedphenotype/query?fields=negatively_regulated_by (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 2.17: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0025439/genes?rows=200
# API 3.4: https://biothings.ncats.io/semmedphenotype/query?fields=produced_by (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.1: https://biothings.ncats.io/semmedphenotype/query?fields=has_part (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.10: https://biothings.ncats.io/semmedphenotype/query?fields=subclass_of (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 3.8: https://biothings.ncats.io/semmedphenotype/query?fields=disrupted_by (POST -d q=C4023112,C0015967,C0018681,C0013404,C0700292,C0007222,C0022660,C4025279,C0006826,C0231528,C0243050,C0021051,C0011849,C0476273,C0010200,C0746102,C2609414,C0027651&scopes=umls)
# API 1.1: https://pending.biothings.io/ebigene2phenotype/query?fields=_id&size=350 (POST -d q=HP:0025439,HP:0000819,HP:0001626,HP:0006528,HP:0002315,HP:0012418,HP:0002664,HP:0002098,HP:0011949,HP:0001945,HP:0001919,HP:0012735,HP:0003326,HP:0002721,HP:0002094,HP:0004887&scopes=gene2phenotype.phenotypes)
# API 2.5: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002315/genes?rows=200&direct=true
# API 2.2: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0000819/genes?rows=200&direct=true
# API 2.31: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002094/genes?rows=200
# API 2.11: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0001919/genes?rows=200&direct=true
# API 2.16: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0004887/genes?rows=200&direct=true
# API 2.26: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0001945/genes?rows=200
# API 2.21: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002315/genes?rows=200
# API 2.15: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002094/genes?rows=200&direct=true
# API 2.30: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002721/genes?rows=200
# API 2.29: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0003326/genes?rows=200
# API 2.14: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002721/genes?rows=200&direct=true
# API 2.3: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0001626/genes?rows=200&direct=true
# API 2.7: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002664/genes?rows=200&direct=true
# API 2.12: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0012735/genes?rows=200&direct=true
# API 2.18: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0000819/genes?rows=200
# API 2.1: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0025439/genes?rows=200&direct=true
# API 2.6: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0012418/genes?rows=200&direct=true
# API 2.4: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0006528/genes?rows=200&direct=true
# API 2.28: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0012735/genes?rows=200
# API 2.10: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0001945/genes?rows=200&direct=true
# API 2.8: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002098/genes?rows=200&direct=true
# API 2.19: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0001626/genes?rows=200
# API 2.9: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0011949/genes?rows=200&direct=true
# API 2.32: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0004887/genes?rows=200
# API 2.24: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002098/genes?rows=200
# API 2.13: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0003326/genes?rows=200&direct=true
# API 2.20: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0006528/genes?rows=200
# API 2.25: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0011949/genes?rows=200
# API 2.27: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0001919/genes?rows=200
# API 2.23: https://api.monarchinitiative.org/api/bioentity/phenotype/HP:0002664/genes?rows=200
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 semmed_phenotype: No hits
# API 1.1 ebi_gene2phenotype: 99 hits
# API 3.2 semmed_phenotype: No hits
# API 3.3 semmed_phenotype: No hits
# API 3.4 semmed_phenotype: No hits
# API 3.5 semmed_phenotype: No hits
# API 2.1 biolink: 5 hits
# API 2.2 biolink: 171 hits
# API 2.3 biolink: 50 hits
# API 2.4 biolink: 22 hits
# API 2.5 biolink: 159 hits
# API 2.6 biolink: 12 hits
# API 2.7 biolink: 151 hits
# API 2.8 biolink: 156 hits
# API 2.9 biolink: 5 hits
# API 2.10 biolink: 180 hits
# API 2.11 biolink: 15 hits
# API 2.12 biolink: 112 hits
# API 2.13 biolink: 108 hits
# API 2.14 biolink: 147 hits
# API 2.15 biolink: 161 hits
# API 2.16 biolink: 15 hits
# API 3.6 semmed_phenotype: No hits
# API 2.17 biolink: No hits
# API 2.18 biolink: No hits
# API 2.19 biolink: No hits
# API 2.20 biolink: No hits
# API 2.21 biolink: No hits
# API 2.22 biolink: No hits
# API 2.23 biolink: No hits
# API 2.24 biolink: No hits
# API 2.25 biolink: No hits
# API 2.26 biolink: No hits
# API 2.27 biolink: 1 hits
# API 2.28 biolink: 1 hits
# API 2.29 biolink: No hits
# API 2.30 biolink: No hits
# API 2.31 biolink: No hits
# API 2.32 biolink: No hits
# API 3.7 semmed_phenotype: No hits
# API 3.8 semmed_phenotype: No hits
# API 3.9 semmed_phenotype: No hits
# API 3.10 semmed_phenotype: No hits
# API 3.11 semmed_phenotype: No hits
# API 3.12 semmed_phenotype: No hits
# API 3.13 semmed_phenotype: No hits
#
# After id-to-object translation, BTE retrieved 985 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 16 unique PhenotypicFeature nodes
# In the #2 query, BTE found 985 unique Gene nodes

# %%
q1_r_graph = q1.fc.G
q1_r_paths_table = q1.display_table_view()

q1_type = re.findall("dispatcher.([a-zA-Z]+)'", str(type(q1.fc)))
q1_type = "".join(q1_type)  ## convert to string

q1 = None  ## clear memory

# %% [markdown]
# Different knowledge sources (APIs) were called in different parts of the query.
#
# In the first part of the query (Disease &rarr; PhenotypicFeature), the following APIs returned results and the following predicates (semantic relationships) were found between SARS and PhenotypicFeatures. The following symptoms/PhenotypicFeatures were found.

# %%
## show that the APIs use different predicates
q1_r_paths_table[['pred1_api', 'pred1_source', 'pred1']].drop_duplicates().sort_values(by = ['pred1_api', 'pred1'])
q1_r_paths_table['node1_name'].unique()
# Out:
#             pred1_api pred1_source          pred1
# 0         BioLink API         hpoa  has_phenotype
# 1  mydisease.info API          hpo     related_to
# array(['DECREASED IMMUNE FUNCTION', 'HEADACHE', 'DIABETES MELLITUS',
#        'FEVER', 'CHRONIC LUNG DISEASE', 'ABNORMAL TISSUE MASS',
#        'BREATHING DIFFICULTIES', 'MUSCLE ACHE', 'ABNORMAL BREATHING',
#        'COUGH',
#        'RESPIRATORY DISTRESS NECESSITATING MECHANICAL VENTILATION',
#        'HYPOXEMIA', 'ABNORMALITY OF THE CARDIOVASCULAR SYSTEM',
#        'ACUTE INFECTIOUS PNEUMONIA', 'ACUTE KIDNEY FAILURE',
#        'PHARYNGITIS'], dtype=object)

# %% [markdown]
# In the second part of the query (PhenotypicFeature &rarr; Gene), the following APIs returned results and the following predicates (semantic relationships) were found between PhenotypicFeatures and Genes.

# %%
## show that the APIs use different predicates
q1_r_paths_table[['pred2_api', 'pred2_source', 'pred2']].drop_duplicates().sort_values(by = ['pred2_api', 'pred2'])
# Out:
#                   pred2_api                                    pred2_source  \
# 628             BioLink API                                     gwascatalog
# 2               BioLink API                              omim,orphanet,hpoa
# 12              BioLink API                      omim,orphanet,clinvar,hpoa
# 20              BioLink API              omim,coriell,orphanet,clinvar,hpoa
# 22              BioLink API                               omim,coriell,hpoa
# 36              BioLink API                                   orphanet,hpoa
# 44              BioLink API                               omim,clinvar,hpoa
# 106             BioLink API                                    clinvar,hpoa
# 144             BioLink API                           orphanet,clinvar,hpoa
# 148             BioLink API                      omim,coriell,orphanet,hpoa
# 170             BioLink API                                       omim,hpoa
# 218             BioLink API                   omim,gwascatalog,coriell,hpoa
# 416             BioLink API  omim,gwascatalog,coriell,orphanet,clinvar,hpoa
# 1756            BioLink API                       omim,coriell,clinvar,hpoa
# 2366            BioLink API                        gwascatalog,coriell,hpoa
# 0     EBIgene2phenotype API                                             EBI
#
#                          pred2
# 628   contributes_to_condition
# 2                has_phenotype
# 12               has_phenotype
# 20               has_phenotype
# 22               has_phenotype
# 36               has_phenotype
# 44               has_phenotype
# 106              has_phenotype
# 144              has_phenotype
# 148              has_phenotype
# 170              has_phenotype
# 218              has_phenotype
# 416              has_phenotype
# 1756             has_phenotype
# 2366             has_phenotype
# 0                   related_to

# %% [markdown]
# Finally, we can see the number of PhenotypicFeatures that were linked to both SARS and to a Gene, the number of Genes returned as output nodes, and the total number of paths from SARS to Gene nodes.

# %%
## show number of unique intermediate nodes
print("There are {0} unique {1}s for {2}.".format( \
    q1_r_paths_table.node1_name.nunique(), q1_intermediate, corona_starting_str))

## show number of unique output nodes
print("There are {0} unique Genes linked to those {1}s.".format( \
    q1_r_paths_table.output_name.nunique(), q1_intermediate))

## show number of paths from disease to genes
print("There are {0} unique paths.".format( \
    q1_r_paths_table.shape[0]))
# Out:
# There are 16 unique PhenotypicFeatures for coronavirus.
# There are 985 unique Genes linked to those PhenotypicFeatures.
# There are 3140 unique paths.

# %% [markdown]
# ### Filtering and scoring

# %% [markdown]
# Filtering involves using edge provenance, like the source this relationship came from and the method used to make this association, to filter out edges (removing nodes in the process).
#
# However, in this particular example, no edges will be removed (we consider almost all the information reliable).

# %%
q1_r_paths_table = filter_table(q1_r_paths_table)

## show number of paths from disease to genes
print("There are {0} unique paths.".format( \
    q1_r_paths_table.shape[0]))
# Out:
# There are 3140 unique paths.

# %% [markdown]
# The scoring process relies on the assumption that the user would be most interested in Genes that share many phenotypes (intermediate nodes) with SARS.
#
# To score individual Gene nodes, we first take a copy of the knowledge graph (KG) and flatten the multi-edges into single edges.
#
# We then count the number of paths from the SARS node to each Gene node. This count is also equivalent to the number of phenotypes/symptoms (PhenotypicFeatures) that SARS and the Gene in common and to the node (out)degree of the Gene in the flattened KG.
#
# Finally, we "normalize" the score by dividing those counts by maximum-possible number of paths from the SARS node to a Gene node. In this case (with  one input node and one intermediate node type), this is equivalent to the number of PhenotypicFeature nodes.
#
# We can then see the top-scored nodes. A score of 1 would mean that the maximum number of PhenotypicFeatures were linked to both SARS and to that Gene. A score closer to 0 would mean that only a few PhenotypicFeatures were linked to both SARS and to that Gene.

# %%
## create scoring table for Genes (output nodes)
q1_scoring = scoring_output(q1_r_paths_table, q1_type)

q1_scoring.head(10)
# Out:
#          score
# HBB     0.3750
# MTHFR   0.3750
# CTNNB1  0.3125
# APC     0.3125
# CSF2RB  0.3125
# WT1     0.3125
# ADA2    0.3125
# GBA     0.3125
# PDGFRA  0.3125
# RET     0.3125

# %% [markdown]
# [TO DO: Actual code depends on graph object (ReasonerStd object or Networkx MultiDiGraph) used.]
#
# We then add the scores and score provenance information to the graph object that will be returned to the ARS. These stored as node attributes on the Gene nodes of the "answer graph".

# %%
# nx.set_node_attributes(q1_r_graph, values = q1_scoring.to_dict(), \
#                        name = 'score')
# nx.set_node_attributes(q1_r_graph, values = '(0-1]', name = 'score_range')
# nx.set_node_attributes(q1_r_graph, values = 'normalized path count', name = 'score_method')
# ## what is a good score, larger or smaller? 
# nx.set_node_attributes(q1_r_graph, values = 'larger', name = 'score_better_direction')  

# ## example of Gene node object with score-related attributes
# q1_r_graph.nodes()['NDUFS1']

# %% [markdown]
# ## Compare answers to bradykinin article

# %% [markdown]
# The ["bradykinin storm" hypothesis article](https://elifesciences.org/articles/59177) describes many gene products that may be linked to COVID-19 symptoms.
#
# We compared BTE's answers to the genes of the biological entities mentioned in the article.

# %%
article_genes = ['AGT', ## AGT = angiotensin precursor. 
                 'AGTR1', 'AGTR2', 'MAS1', ## receptors angiotensin binds to
                 'REN', 'ACE', 'ACE2',  ## enzymes working on angiotensin II precursors
                 'KNG1', 'KLKB1', ## Bradykinin precursor
                 'BDKRB2', 'BDKRB1', ## receptors for bradykinin
                 'NOS1', 'NOS2',  ## nitric oxide synthases: missing NOS3
                 'VDR', 'CYP24A1', 'CYP3A4',  ## vitamin D related
                 'KLK1', 'KLK2', 'KLK3', 'KLK4', 'KLK5', ## KLK = enzymes working on bradykinin precursor 
                 'KLK6', 'KLK7', 'KLK8', 'KLK9', 'KLK10', 
                 'KLK11', 'KLK12', 'KLK13', 'KLK14', 'KLK15', 
                 'KLK11', 'KLK12', 'KLK13', 'KLK14', 'KLK15', 
                 'F12',  ## F12: factor XII related to clotting and bradykinin precursor
                 'SERPING1', ## protease inhibitor, involved in kinin, clotting, complement pathways
                 'CPN1', ## protease linked to kinins, angioedema
                 'HAS1', 'HAS2', 'HAS3', ## hyaluronic acid synthases
                 'HYAL1', 'HYAL2',  ## degrade hyaluronic acid 
                 'CD44',  ## related to hyaluronic acid and immune system
                 'TMSB4X', ## linked to ACE, tissue regeneration
                 'IL2', ## link to CD44, capillary leak syndrome (called VLS in the paper)
                 'APLN', 'APLNR',  ## apelin and its receptor. related to RAS, heart 
                 'MME', ## related to degrading bradykinin, apelin 
                 'NFKB1', 'NFKB2', 'RELA', 'RELB', 'REL', ## genes for NF-kB complex
                 'IKBKG', ## part of IKB kinase complex that activates NFkappaB, degraded by virus 3CLpro protease?
                 'DPP4' ## linked to MERS and immune system
                ]

# %% [markdown]
# Of the gene entities discussed in the bradykinin article, the following are in our results:
# * **NOS1** linked to cough,
# * **SERPING1** linked to breahing difficulties and abnormal breathing
# * **NFKB1**, **NFKB2**, **IKBKG** linked to decreased immune function

# %%
print('Scoring from SARS -> PhenotypicFeature -> Gene query')

## reset index to show placement of genes
q1_scoring_df = q1_scoring.reset_index().rename(columns = {'index': 'output_name'})
q1_scoring_df[q1_scoring_df.output_name.isin(article_genes)]

## show APIs/sources for the underlying info for these answers
q1_r_paths_table[q1_r_paths_table.output_name.isin(article_genes)][['pred1_api']].drop_duplicates()
q1_r_paths_table[q1_r_paths_table.output_name.isin(article_genes)][['pred2_api']].drop_duplicates()
# Out:
# Scoring from SARS -> PhenotypicFeature -> Gene query
#     output_name   score
# 177    SERPING1  0.1250
# 410       IKBKG  0.0625
# 444       NFKB2  0.0625
# 540        NOS1  0.0625
# 896       NFKB1  0.0625
#             pred1_api
# 0         BioLink API
# 1  mydisease.info API
#                pred2_api
# 0  EBIgene2phenotype API
# 2            BioLink API

# %%
q1_r_paths_table[q1_r_paths_table.output_name.isin(article_genes)].node1_name.drop_duplicates()
q1_r_paths_table[q1_r_paths_table.output_name.isin(article_genes)]
# Out:
# 0       DECREASED IMMUNE FUNCTION
# 1134                        COUGH
# 1812       BREATHING DIFFICULTIES
# 1814           ABNORMAL BREATHING
# Name: node1_name, dtype: object
#                                         input input_type          pred1  \
# 0     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 2     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 3     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 122   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 123   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 124   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 125   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1134  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1135  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1812  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1813  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1814  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1815  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
#
#      pred1_source           pred1_api pred1_pubmed pred1_method  \
# 0            hpoa         BioLink API         None         None
# 1             hpo  mydisease.info API         None          TAS
# 2            hpoa         BioLink API         None         None
# 3             hpo  mydisease.info API         None          TAS
# 122          hpoa         BioLink API         None         None
# 123           hpo  mydisease.info API         None          TAS
# 124          hpoa         BioLink API         None         None
# 125           hpo  mydisease.info API         None          TAS
# 1134         hpoa         BioLink API         None         None
# 1135          hpo  mydisease.info API         None          TAS
# 1812         hpoa         BioLink API         None         None
# 1813          hpo  mydisease.info API         None          TAS
# 1814         hpoa         BioLink API         None         None
# 1815          hpo  mydisease.info API         None          TAS
#
#              node1_type                 node1_name       node1_id  \
# 0     PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 1     PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 2     PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 3     PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 122   PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 123   PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 124   PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 125   PhenotypicFeature  DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 1134  PhenotypicFeature                      COUGH  UMLS:C0010200
# 1135  PhenotypicFeature                      COUGH  UMLS:C0010200
# 1812  PhenotypicFeature     BREATHING DIFFICULTIES  UMLS:C0013404
# 1813  PhenotypicFeature     BREATHING DIFFICULTIES  UMLS:C0013404
# 1814  PhenotypicFeature         ABNORMAL BREATHING  UMLS:C0013404
# 1815  PhenotypicFeature         ABNORMAL BREATHING  UMLS:C0013404
#
#               pred2        pred2_source              pred2_api pred2_pubmed  \
# 0        related_to                 EBI  EBIgene2phenotype API         None
# 1        related_to                 EBI  EBIgene2phenotype API         None
# 2     has_phenotype  omim,orphanet,hpoa            BioLink API         None
# 3     has_phenotype  omim,orphanet,hpoa            BioLink API         None
# 122   has_phenotype  omim,orphanet,hpoa            BioLink API         None
# 123   has_phenotype  omim,orphanet,hpoa            BioLink API         None
# 124   has_phenotype  omim,orphanet,hpoa            BioLink API         None
# 125   has_phenotype  omim,orphanet,hpoa            BioLink API         None
# 1134  has_phenotype       orphanet,hpoa            BioLink API         None
# 1135  has_phenotype       orphanet,hpoa            BioLink API         None
# 1812  has_phenotype       orphanet,hpoa            BioLink API         None
# 1813  has_phenotype       orphanet,hpoa            BioLink API         None
# 1814  has_phenotype       orphanet,hpoa            BioLink API         None
# 1815  has_phenotype       orphanet,hpoa            BioLink API         None
#
#      pred2_method output_type output_name      output_id
# 0            None        Gene       IKBKG  NCBIGene:8517
# 1            None        Gene       IKBKG  NCBIGene:8517
# 2            None        Gene       IKBKG  NCBIGene:8517
# 3            None        Gene       IKBKG  NCBIGene:8517
# 122          None        Gene       NFKB2  NCBIGene:4791
# 123          None        Gene       NFKB2  NCBIGene:4791
# 124          None        Gene       NFKB1  NCBIGene:4790
# 125          None        Gene       NFKB1  NCBIGene:4790
# 1134         None        Gene        NOS1  NCBIGene:4842
# 1135         None        Gene        NOS1  NCBIGene:4842
# 1812         None        Gene    SERPING1   NCBIGene:710
# 1813         None        Gene    SERPING1   NCBIGene:710
# 1814         None        Gene    SERPING1   NCBIGene:710
# 1815         None        Gene    SERPING1   NCBIGene:710

# %% [markdown]
# ### Top gene results

# %%
q1_scoring_df.head(20)
# Out:
#    output_name   score
# 0          HBB  0.3750
# 1        MTHFR  0.3750
# 2       CTNNB1  0.3125
# 3          APC  0.3125
# 4       CSF2RB  0.3125
# 5          WT1  0.3125
# 6         ADA2  0.3125
# 7          GBA  0.3125
# 8       PDGFRA  0.3125
# 9          RET  0.3125
# 10        JAK2  0.2500
# 11      PIK3R1  0.2500
# 12         WAS  0.2500
# 13        TP53  0.2500
# 14      SCNN1G  0.2500
# 15        ATP6  0.2500
# 16      SCNN1A  0.2500
# 17      LRRC56  0.2500
# 18        DMPK  0.2500
# 19       TRNL1  0.2500

# %% [markdown]
# Interesting top genes:
# * **CSF2RB** (subunit for GM-CSF immune receptors, including IL3 receptor, IL5 receptor, GM-CSF receptor. these receptors are expressed on innate immune cells).
# * **ADA2** (related to immune system function, levels increased in several immune diseases and cancer)
# * **WAS** (related to clotting and immune deficiency, linked to Wiskott–Aldrich syndrome, interacts with PIK3R1)
# * **SCNN1A**, **SCNN1G** (related to blood pressure, potassium/sodium levels)
# * **ATP6** (mitochondrial gene. linked to neurodegenerative/cardiovascular disease, including Leigh syndrome. Leigh syndrome frequently happens after an event that uses up a lot of energy, including viral infection. Cardiac/neural effects thought to be related to energy production issues)
# * **TRNL1** (mitochondrial gene. Linked to a bunch of diseases https://ghr.nlm.nih.gov/gene/MT-TL1#conditions)
#
# Linked to the biology of genes above:
# Interesting information on GM-CSF (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4553090/)
# * **RET** (related to cancer, enteric nervous system development, kidney development, GM-CSF-related genes)
# * **JAK2** (linked to cancer and to GM-CSF immune receptors)
# * **PIK3R1** (related to cancer, insulin resistance)
#
#
# Not-so-interesting top genes:
# * HBB (hemoglobin)
# * MTHFR (related to cancer, neuronal disease, vascular disease)
# * CTNNB1 (related to cancer, heart disease, cell adhesion)
# * APC (see above on CTNNB1)
# * WT1 (related to cancer)
# * GBA (mutations cause Gaucher's disease)
# * PDGFRA (related to cancer)
# * TP53 (cancer)
# * LRRC56 (linked to primary ciliary dyskinesia, which has a lot of lung infections)
# * DMPK (linked to myotonic dystrophy)

# %%
q1_r_paths_table[q1_r_paths_table['output_name'] == 'CSF2RB']
# Out:
#                                         input input_type          pred1  \
# 1430  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1431  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1432  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1433  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1434  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1435  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1436  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1437  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
# 1438  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  has_phenotype
# 1439  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease     related_to
#
#      pred1_source           pred1_api pred1_pubmed pred1_method  \
# 1430         hpoa         BioLink API         None         None
# 1431          hpo  mydisease.info API         None          TAS
# 1432         hpoa         BioLink API         None         None
# 1433          hpo  mydisease.info API         None          TAS
# 1434         hpoa         BioLink API         None         None
# 1435          hpo  mydisease.info API         None          TAS
# 1436         hpoa         BioLink API         None         None
# 1437          hpo  mydisease.info API         None          TAS
# 1438         hpoa         BioLink API         None         None
# 1439          hpo  mydisease.info API         None          TAS
#
#              node1_type                                         node1_name  \
# 1430  PhenotypicFeature                                              COUGH
# 1431  PhenotypicFeature                                              COUGH
# 1432  PhenotypicFeature                                          HYPOXEMIA
# 1433  PhenotypicFeature                                          HYPOXEMIA
# 1434  PhenotypicFeature                                 ABNORMAL BREATHING
# 1435  PhenotypicFeature                                 ABNORMAL BREATHING
# 1436  PhenotypicFeature  RESPIRATORY DISTRESS NECESSITATING MECHANICAL ...
# 1437  PhenotypicFeature  RESPIRATORY DISTRESS NECESSITATING MECHANICAL ...
# 1438  PhenotypicFeature                         ACUTE INFECTIOUS PNEUMONIA
# 1439  PhenotypicFeature                         ACUTE INFECTIOUS PNEUMONIA
#
#            node1_id          pred2   pred2_source    pred2_api pred2_pubmed  \
# 1430  UMLS:C0010200  has_phenotype  orphanet,hpoa  BioLink API         None
# 1431  UMLS:C0010200  has_phenotype  orphanet,hpoa  BioLink API         None
# 1432  UMLS:C0700292  has_phenotype  orphanet,hpoa  BioLink API         None
# 1433  UMLS:C0700292  has_phenotype  orphanet,hpoa  BioLink API         None
# 1434  UMLS:C0013404  has_phenotype      omim,hpoa  BioLink API         None
# 1435  UMLS:C0013404  has_phenotype      omim,hpoa  BioLink API         None
# 1436  UMLS:C4025279  has_phenotype  orphanet,hpoa  BioLink API         None
# 1437  UMLS:C4025279  has_phenotype  orphanet,hpoa  BioLink API         None
# 1438  UMLS:C4023112  has_phenotype  orphanet,hpoa  BioLink API         None
# 1439  UMLS:C4023112  has_phenotype  orphanet,hpoa  BioLink API         None
#
#      pred2_method output_type output_name      output_id
# 1430         None        Gene      CSF2RB  NCBIGene:1439
# 1431         None        Gene      CSF2RB  NCBIGene:1439
# 1432         None        Gene      CSF2RB  NCBIGene:1439
# 1433         None        Gene      CSF2RB  NCBIGene:1439
# 1434         None        Gene      CSF2RB  NCBIGene:1439
# 1435         None        Gene      CSF2RB  NCBIGene:1439
# 1436         None        Gene      CSF2RB  NCBIGene:1439
# 1437         None        Gene      CSF2RB  NCBIGene:1439
# 1438         None        Gene      CSF2RB  NCBIGene:1439
# 1439         None        Gene      CSF2RB  NCBIGene:1439

# %% [markdown]
# ## ERROR: SARS &rarr; ChemicalSubstance &rarr; Gene

# %% [markdown]
# In this section, we dynamically generate a knowledge graph with paths connecting SARS to genes *with ChemicalSubstance intermediates* (representing the drugs part of the question).
#
# BTE performs the **query path planning** and **query path execution** by deconstructing the query into individual API calls, executing those API calls, and then assembling the results.
#
# The following code block takes about 30 seconds to run.

# %%
## the human user gives this input
q2_output_type = 'Gene'
q2_intermediate = 'ChemicalSubstance'

q2 = FindConnection(input_obj = corona_hint_obj,\
                     output_obj = q2_output_type, \
                    intermediate_nodes = q2_intermediate)
q2.connect(verbose = True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'severe acute respiratory syndrome' and 'Gene'.                   Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
#
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to severe acute respiratory syndrome ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because severe acute respiratory syndrome is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 8 apis:
#
# API 1. scigraph(1 API call)
# API 2. pharos(1 API call)
# API 3. mychem(2 API calls)
# API 4. hmdb(1 API call)
# API 5. cord_disease(1 API call)
# API 6. semmed_disease(15 API calls)
# API 7. scibite(1 API call)
# API 8. mydisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 7.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D045169&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 5.2: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C1175175&scopes=umls)
# API 5.4: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C1175175&scopes=umls)
# API 5.1: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C1175175&scopes=umls)
# API 5.14: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C1175175&scopes=umls)
# API 5.13: https://biothings.ncats.io/semmed/query?fields=derives_info (POST -d q=C1175175&scopes=umls)
# API 5.9: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C1175175&scopes=umls)
# API 5.10: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C1175175&scopes=umls)
# API 5.15: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C1175175&scopes=umls)
# API 5.3: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C1175175&scopes=umls)
# API 5.7: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C1175175&scopes=umls)
# API 5.5: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C1175175&scopes=umls)
# API 6.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:2945&scopes=doid)
# API 5.6: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C1175175&scopes=umls)
# API 5.8: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C1175175&scopes=umls)
# API 5.12: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C1175175&scopes=umls)
# API 5.11: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C1175175&scopes=umls)
# API 2.1: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005091
# API 2.1 pharos failed
# API 8.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0005091
# API 4.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005091
# API 1.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0005091
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 mychem: No hits
# API 4.1 hmdb: No hits
# API 5.1 semmed_disease: No hits
# API 5.2 semmed_disease: 14 hits
# API 3.2 mychem: No hits
# API 5.3 semmed_disease: No hits
# API 6.1 cord_disease: 45 hits
# API 1.1 scigraph: 42 hits
# API 5.4 semmed_disease: 11 hits
# API 5.5 semmed_disease: No hits
# API 8.1 scibite: 50 hits
# API 5.6 semmed_disease: 20 hits
# API 5.7 semmed_disease: No hits
# API 5.8 semmed_disease: 69 hits
# API 5.9 semmed_disease: 28 hits
# API 5.10 semmed_disease: No hits
# API 5.11 semmed_disease: No hits
# API 5.12 semmed_disease: 19 hits
# API 5.13 semmed_disease: No hits
# API 5.14 semmed_disease: No hits
# API 7.1 mydisease: 60 hits
# API 5.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 275 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all Gene entities linked to ChemicalSubstance entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input and 'Gene' as output
#
# BTE found 10 apis:
#
# API 1. scigraph(200 API calls)
# API 2. semmed_chemical(13 API calls)
# API 3. cord_chemical(1 API call)
# API 4. ctd(193 API calls)
# API 5. pharos(200 API calls)
# API 6. mychem(3 API calls)
# API 7. dgidb(198 API calls)
# API 8. scibite(200 API calls)
# API 9. hmdb(200 API calls)
# API 10. chembio(200 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 10.9: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:37586
# API 10.1: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:46761
# API 10.7: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:18059
# API 10.3: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16199
# API 10.8: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:7496
# API 10.2: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:35660
# API 10.5: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:63580
# API 10.6: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26343
# API 10.4: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:24996
# API 10.25: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:47853
# API 10.65: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:135954
# API 10.26: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:71957
# API 10.13: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:15552
# API 10.10: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:78734
# API 10.19: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:30879
# API 10.56: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:83401
# API 10.11: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:18295
# API 10.17: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:36616
# API 10.59: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:35176
# API 10.34: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:36560
# API 10.23: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:135632
# API 10.40: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:17650
# API 10.63: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16962
# API 10.12: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:33292
# API 10.74: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:135679
# API 10.28: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:18282
# API 10.32: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:65769
# API 10.44: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:68657
# API 10.57: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31397
# API 10.61: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:15939
# API 10.22: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:46195
# API 10.20: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:76605
# API 10.15: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:73178
# API 10.18: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:75331
# API 10.79: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:24780
# API 10.48: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31821
# API 10.31: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:28545
# API 10.47: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:46740
# API 10.62: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16134
# API 10.21: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:45409
# API 10.27: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50858
# API 10.75: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16684
# API 10.64: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:48219
# API 10.30: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:44296
# API 10.84: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:25434
# API 7.3: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL455341
# API 10.36: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:59342
# API 10.98: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:82853
# API 10.99: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:28757
# API 10.38: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:8735
# API 10.85: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:8382
# API 10.16: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31548
# API 10.39: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:168396
# API 10.76: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:9555
# API 10.94: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:6538
# API 10.53: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16811
# API 10.72: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26833
# API 10.24: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:45453
# API 10.80: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:58007
# API 10.35: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:49662
# API 10.91: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:63607
# API 10.81: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:47381
# API 10.93: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:33417
# API 7.2: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL866
# API 10.29: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:28790
# API 10.60: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31781
# API 10.14: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:59339
# API 10.52: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50667
# API 10.77: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26345
# API 10.33: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:15379
# API 10.83: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:57947
# API 10.55: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:8459
# API 10.58: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:3638
# API 10.82: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:53242
# API 10.88: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:2639
# API 10.96: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:33569
# API 10.69: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26346
# API 10.95: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:28843
# API 10.49: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:7798
# API 10.43: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:9062
# API 10.68: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50241
# API 10.70: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16480
# API 10.67: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:29136
# API 10.51: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:29194
# API 10.97: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:32016
# API 10.42: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31858
# API 10.37: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:32312
# API 10.71: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:79381
# API 10.73: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:52593
# API 10.46: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:34623
# API 10.86: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:90705
# API 10.78: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:59789
# API 10.41: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16454
# API 10.45: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:79736
# API 10.92: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26344
# API 10.50: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:29309
# API 10.90: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:52553
# API 10.54: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:608828
# API 10.87: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26335
# API 10.89: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:22587
# API 10.66: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:17552
# API 10.100: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:36916
# API 7.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL20
# API 10.102: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:2500
# API 10.101: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:81035
# API 10.107: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:43703
# API 10.104: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:15611
# API 10.103: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:81281
# API 10.106: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:63490
# API 10.105: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:29385
# API 7.4: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL372795
# API 4.2: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D019444
# API 4.4: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C017472
# API 4.1: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D012254
# API 4.6: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C098010
# API 4.3: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D011241
# API 7.6: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL441687
# API 4.5: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D019888
# API 10.111: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26338
# API 10.108: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:2663
# API 10.110: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:6888
# API 10.109: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:57921
# API 4.7: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D014867
# API 4.8: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D003348
# API 10.112: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:7421
# API 10.113: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:86404
# API 4.12: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000069349
# API 4.9: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D019345
# API 10.117: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:17196
# API 10.119: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16844
# API 4.13: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D011480
# API 10.116: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16643
# API 4.10: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D006027
# API 4.14: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D015164
# API 4.11: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D002981
# API 10.114: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:32875
# API 7.34 dgidb failed
# API 7.7: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL304383
# API 7.35 dgidb failed
# API 10.118: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:5938
# API 10.120: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:78161
# API 10.115: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:32785
# API 7.36 dgidb failed
# API 10.128: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:2955
# API 10.126: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16796
# API 10.124: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27899
# API 10.123: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:95002
# API 10.125: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:36066
# API 7.28 dgidb failed
# API 10.122: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16526
# API 10.121: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50122
# API 10.127: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:7789
# API 10.129: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16027
# API 7.8: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL584
# API 7.37 dgidb failed
# API 4.54 ctd failed
# API 4.15: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C038044
# API 4.17: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D013535
# API 4.16: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D002244
# API 7.40 dgidb failed
# API 4.58 ctd failed
# API 7.41 dgidb failed
# API 4.59 ctd failed
# API 10.132: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:15377
# API 7.39 dgidb failed
# API 10.133: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:37684
# API 10.131: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:17076
# API 4.60 ctd failed
# API 10.130: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:3745
# API 7.43 dgidb failed
# API 7.44 dgidb failed
# API 10.135: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:22563
# API 10.134: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:37714
# API 7.45 dgidb failed
# API 7.46 dgidb failed
# API 7.42 dgidb failed
# API 7.47 dgidb failed
# API 10.136: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:2981
# API 4.62 ctd failed
# API 4.63 ctd failed
# API 10.137: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:472805
# API 4.64 ctd failed
# API 10.138: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27539
# API 7.48 dgidb failed
# API 4.65 ctd failed
# API 4.66 ctd failed
# API 7.49 dgidb failed
# API 4.67 ctd failed
# API 7.50 dgidb failed
# API 7.51 dgidb failed
# API 4.19: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D020011
# API 7.52 dgidb failed
# API 4.21: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D008775
# API 7.53 dgidb failed
# API 4.22: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C018279
# API 7.54 dgidb failed
# API 7.55 dgidb failed
# API 10.139: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:62984
# API 7.56 dgidb failed
# API 4.70 ctd failed
# API 10.140: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:32563
# API 10.141: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16196
# API 4.71 ctd failed
# API 7.57 dgidb failed
# API 7.5: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1627731
# API 10.143: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:13248
# API 10.142: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16830
# API 10.144: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:47867
# API 4.20: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C069202
# API 4.74 ctd failed
# API 7.59 dgidb failed
# API 4.26: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C009007
# API 4.23: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D015054
# API 10.145: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:49976
# API 10.146: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:25805
# API 7.9: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1642
# API 4.25: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D001500
# API 10.147: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:33290
# API 4.42: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D006854
# API 7.61 dgidb failed
# API 10.148: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:3561
# API 4.77 ctd failed
# API 7.62 dgidb failed
# API 10.150: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27889
# API 4.78 ctd failed
# API 10.149: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:64276
# API 10.153: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:46915
# API 7.63 dgidb failed
# API 10.152: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:23888
# API 10.151: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:75984
# API 4.27: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000700
# API 4.79 ctd failed
# API 7.64 dgidb failed
# API 7.65 dgidb failed
# API 4.36: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000890
# API 10.154: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:94796
# API 7.66 dgidb failed
# API 7.67 dgidb failed
# API 10.155: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:7769
# API 7.68 dgidb failed
# API 7.69 dgidb failed
# API 7.70 dgidb failed
# API 10.157: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:48433
# API 10.156: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50634
# API 10.158: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50059
# API 7.71 dgidb failed
# API 4.83 ctd failed
# API 4.84 ctd failed
# API 4.30: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C012771
# API 4.18: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D010100
# API 7.72 dgidb failed
# API 4.41: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D017336
# API 10.161: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:35341
# API 10.159: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:49073
# API 10.160: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:67040
# API 4.87 ctd failed
# API 4.88 ctd failed
# API 10.162: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:63175
# API 4.89 ctd failed
# API 7.73 dgidb failed
# API 7.11: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL245019
# API 4.90 ctd failed
# API 4.91 ctd failed
# API 7.76 dgidb failed
# API 4.92 ctd failed
# API 4.93 ctd failed
# API 7.77 dgidb failed
# API 10.163: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:132340
# API 10.164: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:2208
# API 7.75 dgidb failed
# API 10.165: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:58048
# API 4.94 ctd failed
# API 7.78 dgidb failed
# API 4.95 ctd failed
# API 7.79 dgidb failed
# API 7.10: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL76
# API 4.37: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D004221
# API 4.96 ctd failed
# API 4.40: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C031238
# API 10.166: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:30185
# API 7.82 dgidb failed
# API 7.83 dgidb failed
# API 10.167: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:14434
# API 4.34: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000577
# API 4.39: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C120481
# API 7.81 dgidb failed
# API 7.84 dgidb failed
# API 7.85 dgidb failed
# API 7.14: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL633
# API 7.88 dgidb failed
# API 4.32: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D008715
# API 7.89 dgidb failed
# API 4.100 ctd failed
# API 10.168: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:42223
# API 4.101 ctd failed
# API 10.171: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50663
# API 7.87 dgidb failed
# API 4.102 ctd failed
# API 10.170: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:35560
# API 7.90 dgidb failed
# API 10.169: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:87397
# API 10.172: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16914
# API 7.91 dgidb failed
# API 10.173: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:3897
# API 7.15: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL273453
# API 4.103 ctd failed
# API 7.92 dgidb failed
# API 10.175: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:18357
# API 4.104 ctd failed
# API 4.105 ctd failed
# API 10.174: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:24261
# API 4.31: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D022223
# API 7.94 dgidb failed
# API 10.176: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:75958
# API 7.95 dgidb failed
# API 7.96 dgidb failed
# API 7.97 dgidb failed
# API 4.24: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D002945
# API 7.98 dgidb failed
# API 4.35: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D015122
# API 7.99 dgidb failed
# API 10.177: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:59043
# API 4.109 ctd failed
# API 10.179: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:35225
# API 7.100 dgidb failed
# API 10.178: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:45783
# API 4.110 ctd failed
# API 4.111 ctd failed
# API 4.112 ctd failed
# API 4.113 ctd failed
# API 4.114 ctd failed
# API 7.101 dgidb failed
# API 10.182: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:35222
# API 7.102 dgidb failed
# API 4.115 ctd failed
# API 4.116 ctd failed
# API 4.43: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D006514
# API 10.180: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:25847
# API 10.181: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:36044
# API 4.117 ctd failed
# API 7.103 dgidb failed
# API 7.104 dgidb failed
# API 4.38: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D007210
# API 4.29: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C101584
# API 7.105 dgidb failed
# API 7.107 dgidb failed
# API 7.109 dgidb failed
# API 7.108 dgidb failed
# API 7.106 dgidb failed
# API 10.183: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:47916
# API 7.110 dgidb failed
# API 7.112 dgidb failed
# API 7.111 dgidb failed
# API 7.113 dgidb failed
# API 7.12: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL3278446
# API 4.121 ctd failed
# API 10.184: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:72544
# API 4.33: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D006388
# API 7.116 dgidb failed
# API 7.115 dgidb failed
# API 7.22: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1214186
# API 10.187: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27584
# API 4.44: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D006993
# API 10.189: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:17246
# API 7.118 dgidb failed
# API 7.119 dgidb failed
# API 10.185: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:4659
# API 10.186: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26340
# API 4.124 ctd failed
# API 4.125 ctd failed
# API 10.190: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31857
# API 10.188: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:50266
# API 4.126 ctd failed
# API 7.120 dgidb failed
# API 4.127 ctd failed
# API 4.128 ctd failed
# API 10.192: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27690
# API 10.191: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:48912
# API 10.193: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:36067
# API 10.195: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:26334
# API 10.194: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:57433
# API 4.28: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D017332
# API 7.16: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL635
# API 7.123 dgidb failed
# API 7.122 dgidb failed
# API 7.121 dgidb failed
# API 7.124 dgidb failed
# API 4.130 ctd failed
# API 4.45: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D004573
# API 7.127 dgidb failed
# API 10.196: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27140
# API 7.126 dgidb failed
# API 7.128 dgidb failed
# API 7.19: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1615438
# API 4.47: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C023676
# API 10.197: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16919
# API 7.131 dgidb failed
# API 10.198: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:63598
# API 7.130 dgidb failed
# API 10.200: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:137206
# API 10.199: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:9747
# API 4.46: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D012906
# API 4.48: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D012980
# API 4.49: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000086
# API 8.1: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:46761
# API 4.50: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D001216
# API 7.132 dgidb failed
# API 8.3: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16199
# API 8.2: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:35660
# API 4.135 ctd failed
# API 7.133 dgidb failed
# API 8.4: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:24996
# API 7.135 dgidb failed
# API 7.136 dgidb failed
# API 8.5: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:63580
# API 4.51: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C017803
# API 7.134 dgidb failed
# API 7.18: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1159567
# API 8.6: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:26343
# API 8.7: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:18059
# API 8.8: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:7496
# API 8.11: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:18295
# API 8.9: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:37586
# API 8.13: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:15552
# API 7.139 dgidb failed
# API 7.138 dgidb failed
# API 8.12: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:33292
# API 8.10: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:78734
# API 4.138 ctd failed
# API 4.139 ctd failed
# API 4.140 ctd failed
# API 4.141 ctd failed
# API 7.140 dgidb failed
# API 4.142 ctd failed
# API 8.16: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:31548
# API 8.15: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:73178
# API 8.14: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:59339
# API 4.143 ctd failed
# API 4.144 ctd failed
# API 4.53: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D011145
# API 8.18: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:75331
# API 8.19: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:30879
# API 7.142 dgidb failed
# API 7.141 dgidb failed
# API 8.17: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:36616
# API 4.57: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D004928
# API 7.143 dgidb failed
# API 7.145 dgidb failed
# API 8.20: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:76605
# API 4.52: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D013861
# API 7.147 dgidb failed
# API 4.149 ctd failed
# API 7.148 dgidb failed
# API 4.56: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000393
# API 7.149 dgidb failed
# API 8.21: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:45409
# API 4.150 ctd failed
# API 8.22: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:46195
# API 7.144 dgidb failed
# API 4.151 ctd failed
# API 4.152 ctd failed
# API 7.150 dgidb failed
# API 4.153 ctd failed
# API 4.61: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000069605
# API 7.146 dgidb failed
# API 8.23: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:135632
# API 8.24: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:45453
# API 7.13: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL43280
# API 8.25: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:47853
# API 8.26: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:71957
# API 7.17: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL222863
# API 8.27: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:50858
# API 8.28: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:18282
# API 8.29: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:28790
# API 4.55: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D014508
# API 4.68: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C445659
# API 7.153 dgidb failed
# API 8.30: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:44296
# API 7.154 dgidb failed
# API 4.69: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D006460
# API 7.155 dgidb failed
# API 7.156 dgidb failed
# API 8.32: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:65769
# API 8.33: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:15379
# API 8.31: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:28545
# API 4.72: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D014634
# API 4.158 ctd failed
# API 4.159 ctd failed
# API 7.157 dgidb failed
# API 7.159 dgidb failed
# API 8.36: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:59342
# API 7.158 dgidb failed
# API 8.35: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:49662
# API 8.37: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:32312
# API 8.34: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:36560
# API 7.160 dgidb failed
# API 8.38: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:8735
# API 4.73: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C042103
# API 8.39: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:168396
# API 7.161 dgidb failed
# API 7.163 dgidb failed
# API 7.162 dgidb failed
# API 8.41: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16454
# API 7.25: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL376185
# API 8.40: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:17650
# API 8.42: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:31858
# API 7.164 dgidb failed
# API 7.165 dgidb failed
# API 7.166 dgidb failed
# API 4.165 ctd failed
# API 8.43: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:9062
# API 8.44: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:68657
# API 4.76: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D011420
# API 4.80: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D037521
# API 4.81: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D009696
# API 7.167 dgidb failed
# API 8.45: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:79736
# API 7.170 dgidb failed
# API 7.171 dgidb failed
# API 8.46: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:34623
# API 7.169 dgidb failed
# API 4.82: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D016899
# API 7.172 dgidb failed
# API 8.48: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:31821
# API 4.170 ctd failed
# API 8.47: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:46740
# API 8.49: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:7798
# API 4.171 ctd failed
# API 7.173 dgidb failed
# API 4.85: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C011501
# API 4.86: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D003401
# API 8.50: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:29309
# API 8.51: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:29194
# API 4.75: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D018984
# API 8.52: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:50667
# API 8.53: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16811
# API 7.174 dgidb failed
# API 4.97: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D053243
# API 8.54: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:608828
# API 4.177 ctd failed
# API 7.175 dgidb failed
# API 7.176 dgidb failed
# API 4.178 ctd failed
# API 7.177 dgidb failed
# API 7.178 dgidb failed
# API 7.27: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL2311115
# API 8.56: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:83401
# API 4.179 ctd failed
# API 4.180 ctd failed
# API 4.99: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C067172
# API 4.98: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D005424
# API 8.57: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:31397
# API 4.106: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D018130
# API 8.55: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:8459
# API 7.180 dgidb failed
# API 7.181 dgidb failed
# API 4.107: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D014568
# API 8.63: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16962
# API 8.61: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:15939
# API 7.20: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL6
# API 8.62: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16134
# API 8.58: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:3638
# API 8.59: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:35176
# API 8.60: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:31781
# API 8.64: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:48219
# API 4.118: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D017968
# API 7.184 dgidb failed
# API 7.185 dgidb failed
# API 7.183 dgidb failed
# API 7.187 dgidb failed
# API 7.186 dgidb failed
# API 4.108: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C009873
# API 7.21: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1650
# API 4.119: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D009173
# API 4.120: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C006069
# API 4.122: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D061466
# API 8.65: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:135954
# API 7.189 dgidb failed
# API 8.67: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:29136
# API 8.66: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:17552
# API 8.68: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:50241
# API 7.30: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL384759
# API 4.123: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000809
# API 8.72: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:26833
# API 8.69: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:26346
# API 4.131: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C451427
# API 8.71: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:79381
# API 8.70: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16480
# API 8.73: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:52593
# API 7.190 dgidb failed
# API 4.132: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D007510
# API 7.31: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1200469
# API 8.74: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:135679
# API 4.193 ctd failed
# API 8.77: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:26345
# API 8.75: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16684
# API 8.76: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:9555
# API 7.193 dgidb failed
# API 8.78: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:59789
# API 7.194 dgidb failed
# API 7.195 dgidb failed
# API 4.133: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D020156
# API 8.80: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:58007
# API 8.79: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:24780
# API 7.196 dgidb failed
# API 7.197 dgidb failed
# API 8.81: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:47381
# API 8.82: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:53242
# API 7.198 dgidb failed
# API 4.134: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D001562
# API 4.136: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C013738
# API 4.146: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C025953
# API 4.137: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D011728
# API 8.83: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:57947
# API 8.84: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:25434
# API 8.85: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:8382
# API 8.86: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:90705
# API 4.145: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D007659
# API 4.147: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C093844
# API 7.29: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL76101
# API 4.148: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D019301
# API 4.155: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D017998
# API 4.154: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C001899
# API 4.129: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D007213
# API 8.87: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:26335
# API 4.157: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D011108
# API 7.26: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1201420
# API 4.160: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C005864
# API 4.161: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D002918
# API 8.92: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:26344
# API 8.91: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:63607
# API 4.164: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C097613
# API 4.156: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D004364
# API 4.162: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C027451
# API 8.93: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:33417
# API 8.90: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:52553
# API 8.88: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:2639
# API 8.94: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:6538
# API 8.89: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:22587
# API 8.96: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:33569
# API 8.95: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:28843
# API 8.97: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:32016
# ...
# API 7.31 dgidb: 4 hits
# API 7.32 dgidb: No hits
# API 7.33 dgidb: No hits
# API 7.38 dgidb: No hits
# API 7.58 dgidb: No hits
# API 7.60 dgidb: No hits
# API 7.74 dgidb: 6 hits
# API 7.80 dgidb: 3 hits
# API 7.86 dgidb: No hits
# API 7.93 dgidb: No hits
# API 7.114 dgidb: No hits
# API 7.117 dgidb: 1 hits
# API 7.125 dgidb: No hits
# API 7.129 dgidb: No hits
# API 7.137 dgidb: No hits
# API 7.151 dgidb: No hits
# API 7.152 dgidb: No hits
# API 7.168 dgidb: No hits
# API 7.179 dgidb: No hits
# API 7.182 dgidb: No hits
# API 7.188 dgidb: 15 hits
# API 7.191 dgidb: No hits
# API 7.192 dgidb: 9 hits
# API 6.1 hmdb: No hits
# API 6.2 hmdb: No hits
# API 6.3 hmdb: 10 hits
# API 6.4 hmdb: No hits
# API 6.5 hmdb: 2 hits
# API 6.6 hmdb: No hits
# API 6.7 hmdb: No hits
# API 6.8 hmdb: 13 hits
# API 6.9 hmdb: No hits
# API 6.10 hmdb: 6 hits
# API 6.11 hmdb: 11 hits
# API 6.12 hmdb: No hits
# API 6.13 hmdb: 3 hits
# API 6.14 hmdb: No hits
# API 6.15 hmdb: No hits
# API 6.16 hmdb: No hits
# API 6.17 hmdb: No hits
# API 6.18 hmdb: No hits
# API 6.19 hmdb: No hits
# API 6.20 hmdb: No hits
# API 6.21 hmdb: 16 hits
# API 6.22 hmdb: 4 hits
# API 6.23 hmdb: No hits
# API 6.24 hmdb: No hits
# API 6.25 hmdb: No hits
# API 6.26 hmdb: No hits
# API 6.27 hmdb: No hits
# API 6.28 hmdb: No hits
# API 6.29 hmdb: 27 hits
# API 6.30 hmdb: No hits
# API 6.31 hmdb: No hits
# API 6.32 hmdb: No hits
# API 6.33 hmdb: 197 hits
# API 6.34 hmdb: No hits
# API 6.35 hmdb: No hits
# API 6.36 hmdb: No hits
# API 6.37 hmdb: No hits
# API 6.38 hmdb: No hits
# API 6.39 hmdb: 8 hits
# API 6.40 hmdb: 17 hits
# API 6.41 hmdb: No hits
# API 6.42 hmdb: No hits
# API 6.43 hmdb: 1 hits
# API 6.44 hmdb: 2 hits
# API 6.45 hmdb: No hits
# API 6.46 hmdb: No hits
# API 6.47 hmdb: No hits
# API 6.48 hmdb: 3 hits
# API 6.49 hmdb: 5 hits
# API 6.50 hmdb: No hits
# API 6.51 hmdb: No hits
# API 6.52 hmdb: 5 hits
# API 6.53 hmdb: No hits
# API 6.54 hmdb: No hits
# API 6.55 hmdb: No hits
# API 6.56 hmdb: No hits
# API 6.57 hmdb: No hits
# API 6.58 hmdb: 9 hits
# API 6.59 hmdb: No hits
# API 6.60 hmdb: 7 hits
# API 6.61 hmdb: No hits
# API 6.62 hmdb: 83 hits
# API 6.63 hmdb: 4 hits
# API 6.64 hmdb: No hits
# API 6.65 hmdb: No hits
# API 6.66 hmdb: 220 hits
# API 6.67 hmdb: No hits
# API 6.68 hmdb: No hits
# API 6.69 hmdb: No hits
# API 6.70 hmdb: 6 hits
# API 6.71 hmdb: No hits
# API 6.72 hmdb: No hits
# API 6.73 hmdb: No hits
# API 6.74 hmdb: No hits
# API 6.75 hmdb: No hits
# API 6.76 hmdb: 2 hits
# API 6.77 hmdb: No hits
# API 6.78 hmdb: 129 hits
# API 6.79 hmdb: No hits
# API 6.80 hmdb: No hits
# API 6.81 hmdb: No hits
# API 6.82 hmdb: No hits
# API 6.83 hmdb: 10 hits
# API 6.84 hmdb: No hits
# API 6.85 hmdb: 4 hits
# API 6.86 hmdb: No hits
# API 6.87 hmdb: No hits
# API 6.88 hmdb: 12 hits
# API 6.89 hmdb: No hits
# API 6.90 hmdb: No hits
# API 6.91 hmdb: 2 hits
# API 6.92 hmdb: No hits
# API 6.93 hmdb: No hits
# API 6.94 hmdb: 1 hits
# API 6.95 hmdb: No hits
# API 6.96 hmdb: No hits
# API 6.97 hmdb: No hits
# API 6.98 hmdb: No hits
# API 6.99 hmdb: No hits
# API 6.100 hmdb: No hits
# API 6.101 hmdb: No hits
# API 6.102 hmdb: No hits
# API 6.103 hmdb: No hits
# API 6.104 hmdb: No hits
# API 6.105 hmdb: No hits
# API 6.106 hmdb: No hits
# API 6.107 hmdb: No hits
# API 6.108 hmdb: No hits
# API 6.109 hmdb: No hits
# API 6.110 hmdb: 1 hits
# API 6.111 hmdb: No hits
# API 6.112 hmdb: No hits
# API 6.113 hmdb: No hits
# API 6.114 hmdb: No hits
# API 6.115 hmdb: No hits
# API 6.116 hmdb: No hits
# API 6.117 hmdb: No hits
# API 6.118 hmdb: No hits
# API 6.119 hmdb: No hits
# API 6.120 hmdb: No hits
# API 6.121 hmdb: 2 hits
# API 6.122 hmdb: 105 hits
# API 6.123 hmdb: No hits
# API 6.124 hmdb: No hits
# API 6.125 hmdb: No hits
# API 6.126 hmdb: 17 hits
# API 6.127 hmdb: 10 hits
# API 6.128 hmdb: 3 hits
# API 6.129 hmdb: 262 hits
# API 6.130 hmdb: 1 hits
# API 6.131 hmdb: 1 hits
# API 6.132 hmdb: 1126 hits
# API 6.133 hmdb: No hits
# API 6.134 hmdb: No hits
# API 6.135 hmdb: No hits
# API 6.136 hmdb: No hits
# API 6.137 hmdb: 7 hits
# API 6.138 hmdb: No hits
# API 6.139 hmdb: No hits
# API 6.140 hmdb: No hits
# API 6.141 hmdb: 11 hits
# API 6.142 hmdb: 5 hits
# API 6.143 hmdb: No hits
# API 6.144 hmdb: No hits
# API 6.145 hmdb: No hits
# API 6.146 hmdb: No hits
# API 6.147 hmdb: No hits
# API 6.148 hmdb: 2 hits
# API 6.149 hmdb: No hits
# API 6.150 hmdb: No hits
# API 6.151 hmdb: 4 hits
# API 6.152 hmdb: No hits
# API 6.153 hmdb: No hits
# API 6.154 hmdb: No hits
# API 6.155 hmdb: No hits
# API 6.156 hmdb: No hits
# API 6.157 hmdb: No hits
# API 6.158 hmdb: No hits
# API 6.159 hmdb: No hits
# API 6.160 hmdb: No hits
# API 6.161 hmdb: No hits
# API 6.162 hmdb: No hits
# API 6.163 hmdb: No hits
# API 6.164 hmdb: No hits
# API 6.165 hmdb: 13 hits
# API 6.166 hmdb: No hits
# API 6.167 hmdb: No hits
# API 6.168 hmdb: No hits
# API 6.169 hmdb: No hits
# API 6.170 hmdb: No hits
# API 6.171 hmdb: 1 hits
# API 6.172 hmdb: 14 hits
# API 6.173 hmdb: 1 hits
# API 6.174 hmdb: No hits
# API 6.175 hmdb: 23 hits
# API 6.176 hmdb: No hits
# API 6.177 hmdb: No hits
# API 6.178 hmdb: No hits
# API 6.179 hmdb: No hits
# API 6.180 hmdb: No hits
# API 6.181 hmdb: No hits
# API 6.182 hmdb: No hits
# API 6.183 hmdb: No hits
# API 6.184 hmdb: No hits
# API 6.185 hmdb: 6 hits
# API 6.186 hmdb: No hits
# API 6.187 hmdb: No hits
# API 6.188 hmdb: No hits
# API 6.189 hmdb: 69 hits
# API 6.190 hmdb: No hits
# API 6.191 hmdb: No hits
# API 6.192 hmdb: 9 hits
# API 6.193 hmdb: No hits
# API 6.194 hmdb: 5 hits
# API 6.195 hmdb: No hits
# API 6.196 hmdb: No hits
# API 6.197 hmdb: No hits
# API 6.198 hmdb: 2 hits
# API 6.199 hmdb: No hits
# API 6.200 hmdb: No hits
# API 3.6 semmed_chemical: 1 hits
# API 3.7 semmed_chemical: 18610 hits
# API 3.8 semmed_chemical: 1 hits
# API 3.9 semmed_chemical: 3646 hits
# API 2.1 cord_chemical: 20307 hits
# API 4.1 ctd: 46 hits
# API 4.2 ctd: No hits
# API 4.3 ctd: 41 hits
# API 4.4 ctd: No hits
# API 4.5 ctd: 53 hits
# API 4.6 ctd: No hits
# API 4.7 ctd: 73 hits
# API 4.8 ctd: 34 hits
# API 4.9 ctd: 176 hits
# API 4.10 ctd: 9 hits
# API 4.11 ctd: 4 hits
# API 4.12 ctd: 23 hits
# API 4.13 ctd: 6 hits
# API 4.14 ctd: No hits
# API 4.15 ctd: 47 hits
# API 4.16 ctd: 89 hits
# API 4.17 ctd: No hits
# API 4.18 ctd: 4588 hits
# API 4.19 ctd: No hits
# API 4.20 ctd: No hits
# API 4.21 ctd: 142 hits
# API 4.22 ctd: 1 hits
# API 4.23 ctd: 235 hits
# API 4.24 ctd: 9634 hits
# API 4.25 ctd: 3 hits
# API 4.26 ctd: 22 hits
# API 4.27 ctd: 1 hits
# API 4.28 ctd: 18 hits
# API 4.29 ctd: 5 hits
# API 4.30 ctd: 24 hits
# API 4.31 ctd: No hits
# API 4.32 ctd: 3640 hits
# API 4.33 ctd: 17 hits
# API 4.34 ctd: 17 hits
# API 4.35 ctd: 301 hits
# API 4.36 ctd: No hits
# API 4.37 ctd: 924 hits
# API 4.38 ctd: No hits
# API 4.39 ctd: 4 hits
# API 4.40 ctd: 51 hits
# API 4.41 ctd: 36 hits
# API 4.42 ctd: 253 hits
# API 4.43 ctd: No hits
# API 4.44 ctd: No hits
# API 4.45 ctd: 1 hits
# API 4.46 ctd: 1309 hits
# API 4.47 ctd: 65 hits
# API 4.48 ctd: 63 hits
# API 4.49 ctd: 68 hits
# API 4.50 ctd: 1 hits
# API 4.51 ctd: 194 hits
# API 4.52 ctd: No hits
# API 4.53 ctd: No hits
# API 4.55 ctd: 46 hits
# API 4.56 ctd: 2362 hits
# API 4.57 ctd: 2 hits
# API 4.61 ctd: 7 hits
# API 4.68 ctd: No hits
# API 4.69 ctd: No hits
# API 4.72 ctd: 13 hits
# API 4.73 ctd: 6 hits
# API 4.75 ctd: No hits
# API 4.76 ctd: 1 hits
# API 4.80 ctd: No hits
# API 4.81 ctd: No hits
# API 4.82 ctd: No hits
# API 4.85 ctd: No hits
# API 4.86 ctd: 14 hits
# API 4.97 ctd: No hits
# API 4.98 ctd: 27 hits
# API 4.99 ctd: 18 hits
# API 4.106 ctd: No hits
# API 4.107 ctd: No hits
# API 4.108 ctd: 3 hits
# API 4.118 ctd: 10 hits
# API 4.119 ctd: 136 hits
# API 4.120 ctd: 3 hits
# API 4.122 ctd: 16 hits
# API 4.123 ctd: 1 hits
# API 4.129 ctd: 5151 hits
# API 4.131 ctd: 6 hits
# API 4.132 ctd: 29 hits
# API 4.133 ctd: 47 hits
# API 4.134 ctd: 13 hits
# API 4.136 ctd: 42 hits
# API 4.137 ctd: 1 hits
# API 4.145 ctd: 4 hits
# API 4.146 ctd: No hits
# API 4.147 ctd: 35 hits
# API 4.148 ctd: 296 hits
# API 4.154 ctd: 632 hits
# API 4.155 ctd: 30 hits
# API 4.156 ctd: No hits
# API 4.157 ctd: No hits
# API 4.160 ctd: No hits
# API 4.161 ctd: No hits
# API 4.162 ctd: 4 hits
# API 4.163 ctd: 5 hits
# API 4.164 ctd: No hits
# API 4.166 ctd: 54 hits
# API 4.167 ctd: 2 hits
# API 4.168 ctd: No hits
# API 4.169 ctd: 1251 hits
# API 4.172 ctd: 127 hits
# API 4.173 ctd: 1 hits
# API 4.174 ctd: 65 hits
# API 4.175 ctd: 21 hits
# API 4.176 ctd: 9 hits
# API 4.181 ctd: 188 hits
# API 4.182 ctd: 7 hits
# API 4.183 ctd: 1578 hits
# API 4.184 ctd: 12 hits
# API 4.185 ctd: 32 hits
# API 4.186 ctd: 10 hits
# API 4.187 ctd: 4 hits
# API 4.188 ctd: 10 hits
# API 4.189 ctd: 5 hits
# API 4.190 ctd: 2 hits
# API 4.191 ctd: 13 hits
# API 4.192 ctd: 24 hits
# API 3.10 semmed_chemical: 14774 hits
# API 3.11 semmed_chemical: 16 hits
# API 3.12 semmed_chemical: No hits
# API 3.13 semmed_chemical: 8333 hits
# Traceback (most recent call last):
#
#   File "/Users/jay/miniconda3/envs/BTE/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-33-e74a2f10f092>", line 8, in <module>
#     q2.connect(verbose = True)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/user_query_dispatcher.py", line 1161, in connect
#     self.fc.connect(verbose=verbose)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/user_query_dispatcher.py", line 917, in connect
#     self.seqd[query_id].query(verbose=verbose)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/user_query_dispatcher.py", line 388, in query
#     self.G, out_equ_ids = add_equivalent_ids_to_nodes(self.G, self.idr)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/utils/networkx.py", line 90, in add_equivalent_ids_to_nodes
#     equivalent_ids = IDResolver.resolve_ids(idc_inputs)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/id_resolver.py", line 63, in resolve_ids
#     self.responses, _ = self.caller.call_apis(self.api_call_inputs, loop=loop)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/apicall.py", line 230, in call_apis
#     return (loop.run_until_complete(self.run(inputs, verbose=verbose)), self.log)
#
#   File "/Users/jay/miniconda3/envs/BTE/lib/python3.7/asyncio/base_events.py", line 587, in run_until_complete
#     return future.result()
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/apicall.py", line 192, in run
#     responses = await asyncio.gather(*tasks)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/apicall.py", line 178, in call_one_api
#     res = await self.call_one_arbitrary_api(_input, session, verbose=verbose)
#
#   File "/Users/jay/Desktop/biothings_explorer/biothings_explorer/apicall.py", line 51, in call_one_arbitrary_api
#     str(request_body["body"]).replace("{inputs[0]}", _input["value"])
#
#   File "<string>", line 1
#     {'q': 'PTGS1,PTGS2,AKR1C1,CYP2C9,BDKRB1,MGMT,ALDOA,EEF1A1,ENO1,GAPDHS,NME1,P4HB,PDIA3,PRDX1,PSPH,TPI1,TUFM,ESR1,IL3,MT2A,CCS,HDAC1,HDAC4,MPG,SEMG1,SOD1,HDAC8,SIVA1,GLRA1,MDM2,INS,UTRN,ASPA,S100A8,S100A9,MMP9,TP73,S100A2,TP53,MT3,PDCD6,DAND5,MT1A,A1BG,A2M,AGT,AHSG,APCS,APOA1,APOA2,APOA4,APOBR,APOE,APOL1,C1QB,C1QC,C1R,C1S,C3,C4B,C4BPA,C4BPB,C5,BRCC3,C8A,C8B,C8G,CFB,CFH,CFI,CLU,CP,CPN1,CPN2,DCD,DSP,F12,F13B,F2,FCN3,FGA,FN1,GSN,HBA1,HBB,HPR,HRNR,IGFALS,IGHA1,IGHM,IGKV1-17,IGLV3-21,ITIH1,ITIH2,ITIH3,ITIH4,JCHAIN,JUP,KLKB1,KNG1,KRT1,KRT10,KRT14,KRT16,KRT2,KRT5,KRT6A,KRT9,ORM2,PGLYRP2,PON1,PZP,S100A7,SEPP1,SERPINA1,SERPINA3,SERPINA4,SERPINA6,SERPIND1,SHBG,TF,TTR,VTN,APLP1,APLP2,APP,PARP1,CA1,CPE,ADH1C,IDE,HRH1,HSD11B1,TNF,CASP3,LPL,gp41,CYP2C19,CYP2E1,FURIN,CYP1A2,kcsA,CHRNA9,Kcnma1,KCNA1,PLG,PLAUR,SERPINE1,SERPINB2,SERPINA5,LRP2,ST14,NID1,MMP12,PLA2G2A,PTGR2,PPARG,GLO1,PTGDR2,PPARA,AKR1C3,CES1,UGT1A9,UGT1A1,UGT2B7,IMPDH1,IMPDH2,L,PB1,ADK,NT5C2,BCR,KIT,RET,NTRK1,CSF1R,PDGFRA,DDR1,ABL1,PDGFRB,CYP3A4,CYP3A5,CYP3A7,CYP2D6,CYP2C8,MAOA,MAOB,SCN5A,SCN4A,KCNH2,RYR2,parC,gyrA,NR3C2,NR3C1,CYP11B1,CYP11B2,CYP17A1,HRH2,HRH3,HRH4,SLC18A2,HNMT,PMP2,PPARD,RXRA,GRIN2D,GRIN1,GRIN3B,GRIN3A,SLC6A2,SCN10A,CYP2B6,CACNA1I,PPARGC1B,CYP1A1,CYP2A6,CYP2J2,ALDH2,DBH,pol,IFNAR2,IFNAR1,amtB,SLC6A4,HTR2A,HTR3A,HTR3B,NEU2,GSTA2,TLR9,GST,HMGB1,GSTM1,ACE2,ANXA1,AKR1D1,SRD5A2,HSD11B2,CYP1B1,PADI4,lamB,SLC1A5,ASRGL1,NARS2,ASNS,NARS,GUCY1A2,IDO1,rplA,UGT1A7,UGT1A6,MTNR1A,MTNR1B,RORB,CALM1,MPO,EPX,CALR,ASMT,NQO2,CYP19A1,ADORA2A,ADORA2B,ADORA3,ADORA1,ADA,GLS2,GLUL,CPS1,DRD2,HTR2C,ADRA1A,CHRM1,HP,APOB,HPX,HRG,F11,APOBEC1,SEMG2,CA2,ADRA1B,ADRA1D,ADRA2A,ADRA2B,ADRA2C,ADRB1,ADRB2,ADRB3,PAH,SLC18A1,rdmB,ermC',taqIM,rsrIM,ACSL4,RXRB,RXRG,AKR1B10,AKR1B1,ARG1,CTNNB1,yedY,DHFR,S100A1,S100A12,S100B,S100A13,FMO1,FMO3,NEU1,CYP2C18,UGT1A3,UGT2B4,ALOX5,CREB1,PDE4B,PRKAB1,HINT1,PDE4D,ACSS2,PRKAA1,ADCY1,ACSL1,FBP1,AMPD1,APRT,MT-CO1,NOX1,PTGES3,TRPV1,UGT2B15,SULT1A1,SULT1A3,NAT2,FAAH,GSTP1,PRSS1,TMPRSS2,CCK,HPRT1,PPAT,TPMT,XDH,AOX1,CA4,CA12,CA14,CA3,CA7,AQP1,ATP1A1,ATP1A2,ATP1A3,P2RY12,PTGIR,PTGIS,SCNN1A,SCNN1B,SCNN1G,SCNN1D,AOC1,ASIC2,ASIC1,SLC9A1,PLAU,CHRM2,CHRM3,CHRM4,CHRM5,CHRNA4,CHRNB2,ATOX1,CYP4A11,nat,BCHE,GSTT1,NQO1,CSNK2A1,actIII,fabZ,AHR,NTSR2,UGT2B10,GNMT,AMD1,MAT2A,CBS,MAT1A,COMT,CMTR1,AS3MT,SRM,rpsL,CKM,CKMT1A,CKB,CKMT2,SLC6A8,GAMT,NR1I2,ALPPL2,MTRR,MTR,METAP2,BHMT,BHMT2,MTHFR,MSRB2,MSRB1,MSRA,MARS,MARS2,MAT2B,ADSSL1,fusA,der,gmm,engB,EIF2S3,GNAI1,ffh,GNAT1,tufB,RAB9A,RHEB,CDC42,tufA,ARF1,EEF2,relA,RAP2A,EFTUD1,ARL1,RAN,RAB7A,IRGC,GSPT1,RAB5A,HRAS,RHOA,ARF4,TGM2,GMDS,RAB11A,RALA,purA,tuf,ARL5B,ftsZ,TGM3,rab6,RAB8B,ARF6,ARL3,NME2,gmd,RAC1,rsgA,SAR1B,Adss,ARL5A,CAH1,CAH2,ca1,CA5A,CA13,CA5B,CA6,CA9,CAN2,NCE103,ca,Ca13,cynT,Ca15,CA,Ca7,CTS1,mtcA1,mtcA2,Hsd11b1,gag-pol,OPRM1,DRD1,SLC6A3,OPRK1,OPRD1,EGFR,LCK,FYN,TBXAS1,MAPK3,MAPK14,TACR2,Ar,ALOX15,PGR,ABCB1,PRNP,Scn5a,HTR2B,HTR6,DRD3,DRD4,EDNRA,ERBB2,CCR2,Htr1b,BDKRB2,MC4R,MC5R,MC3R,CCR4,Pgrmc1,SIGMAR1,THRB,THRA,EBP,KCNA7,HCN4,CACNA1H,THAP1,lef,ERG2,SQLE,FDFT1,Nr3c2,SLC28A1,STAT3,Ntsr2,PTGER2,Akr1b1,CXCL8,PTGES,AKR1C4,AR,Ptgds,ABCC1,AKR1C2,Ptgs2,Ptgs1,DHRS9,Nos2,SLC47A1,FNTA,FNTB,Hrh4,Hrh3,TAAR1,Hrh1,FFAR1,Fabp1,FABP5,FABP1,LOX1.1,F3,FABP4,TOP1,FFAR4,TERT,TEK,UGT1A10,CXCR1,ASIC3,SLC22A2,Plg,KLK1,SLC47A2,HGFAC,Chrm2,Chrm5,SLC22A1,Chrm1,nAChRalpha5,Ache,Chrm3,Chrm4,punA,PNP,ABCC4,ABCC5,RORA,SABP2,PPO2,Slc22a20,PPP3CA,GPR39,Gpr39,NR1H4,SLC6A15,rpl10,SCN9A,SCN1A,GRIN2A,GRIN2B,GRIN2C,Zmpste24,protease,Maob,TRPM4,SRC,TRPM2,panE,LDHA,Ak2,DNPH1,Dnph1,env,PTGER4,PTGER1,NS5B,ENPP1,SLC9A5,NHE1,Aoc3,gyrB,parE,RCE1,PDE4A,CCR5,CXCR2,MGLL,Aldh2,TSPO,glmU,NEU3,HTR1A,Adra1b,Drd1,Drd2,Drd3,Drd4,Drd5,TPR,PDR5,SCN2A,SCN3A,GFER,Htr1a,Adra1a,luxS,NOS2,Nr3c1,GABRA1,GABRA2,GABRA3,GABRA4,GABRA5,GABRA6,GABRB1,GABRB2,GABRB3,GABRD,GABRE,GABRG1,GABRG2,GABRG3,GABRP,GABRQ,PREP,CDK1,ALOX5AP,MB,CNR1,NR1I3,GUCY1A3,GUCY1B2,GUCY1B3,Agtr1,Maoa,RARG,TRPC5,ABCB11,Abcb11,Pparg,FGFR2,FGFR1,EPHB1,EPHB4,BMX,INSR,JAK2,MAPK10,SLC22A3,FLT3,MAPK9,KDR,GAK,ZAK,MELK,SYK,RAF1 ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# SyntaxError: invalid syntax

# %%
q2_r_graph = q2.fc.G
q2_r_paths_table = q2.display_table_view()

q2_type = re.findall("dispatcher.([a-zA-Z]+)'", str(type(q2.fc)))
q2_type = "".join(q2_type)  ## convert to string

q2 = None ## clear memory

# %% [markdown]
# Different knowledge sources (APIs) were called in different parts of the query.
#
# In the first part of the query (Disease &rarr; ChemicalSubstance), the following APIs returned results and the following predicates (semantic relationships) were found between SARS and ChemicalSubstances.

# %%
## show that the APIs use different predicates, one each
q2_r_paths_table[['pred1_api', 'pred1_source', 'pred1']].drop_duplicates().sort_values(by = ['pred1_api', 'pred1'])
# Out:
#                          pred1_api pred1_source         pred1
# 53     Automat CORD19 Scigraph API     scigraph    related_to
# 52                Automat HMDB API         hmdb    related_to
# 17              SEMMED Disease API       SEMMED   affected_by
# 0               SEMMED Disease API       SEMMED     caused_by
# 19              SEMMED Disease API       SEMMED  disrupted_by
# 10179           SEMMED Disease API       SEMMED  prevented_by
# 5               SEMMED Disease API       SEMMED    related_to
# 1               SEMMED Disease API       SEMMED    treated_by
# 46              mydisease.info API          ctd    related_to

# %% [markdown]
# In the second part of the query (ChemicalSubstance &rarr; Gene), the following APIs returned results and the following predicates (semantic relationships) were found between ChemicalSubstances and Genes.

# %%
## show that the APIs use different predicates
q2_r_paths_table[['pred2_api', 'pred2_source', 'pred2']].drop_duplicates().sort_values(by = ['pred2_api', 'pred2'])
# Out:
#                          pred2_api  \
# 18904          Automat CHEMBIO API
# 5230    Automat CORD19 Scibite API
# 5178   Automat CORD19 Scigraph API
# 6001              Automat HMDB API
# 22243           Automat PHAROS API
# 5057             CORD Chemical API
# 5065                       CTD API
# 6015                     DGIdb API
# 8809                     DGIdb API
# 40863                    DGIdb API
# 53761                    DGIdb API
# 22226              MyChem.info API
# 5071               MyChem.info API
# 6014               MyChem.info API
# 2              SEMMED Chemical API
# 14             SEMMED Chemical API
# 27             SEMMED Chemical API
# 0              SEMMED Chemical API
# 16             SEMMED Chemical API
# 6              SEMMED Chemical API
# 8              SEMMED Chemical API
#
#                                        pred2_source  \
# 18904                                       chembio
# 5230                                        scibite
# 5178                                       scigraph
# 6001                                           hmdb
# 22243                                        pharos
# 5057                Translator Text Mining Provider
# 5065                                            CTD
# 6015                GuideToPharmacologyInteractions
# 8809                                       DrugBank
# 40863  GuideToPharmacologyInteractions,DrugBank,TTD
# 53761      GuideToPharmacologyInteractions,DrugBank
# 22226                                      drugbank
# 5071                                       drugbank
# 6014                                    drugcentral
# 2                                            SEMMED
# 14                                           SEMMED
# 27                                           SEMMED
# 0                                            SEMMED
# 16                                           SEMMED
# 6                                            SEMMED
# 8                                            SEMMED
#
#                                   pred2
# 18904                        related_to
# 5230                         related_to
# 5178                         related_to
# 6001                         related_to
# 22243                        related_to
# 5057                         related_to
# 5065                         related_to
# 6015          physically_interacts_with
# 8809          physically_interacts_with
# 40863         physically_interacts_with
# 53761         physically_interacts_with
# 22226  metabolic_processing_affected_by
# 5071          physically_interacts_with
# 6014          physically_interacts_with
# 2                         coexists_with
# 14              negatively_regulated_by
# 27                 negatively_regulates
# 0             physically_interacts_with
# 16              positively_regulated_by
# 6                  positively_regulates
# 8                           produced_by

# %% [markdown]
# Finally, we can see the number of ChemicalSubstances that were linked to both SARS and to a Gene as well as the number of Genes returned as output nodes.

# %%
## show number of unique intermediate nodes
print("There are {0} unique {1}s for {2}.".format( \
    q2_r_paths_table.node1_name.nunique(), q2_intermediate, corona_starting_str))

## show number of unique output nodes
print("There are {0} unique Genes linked to those {1}s.".format( \
    q2_r_paths_table.output_name.nunique(), q2_intermediate))

# %% [markdown]
# ### Filtering and scoring

# %% [markdown]
# Filtering involves using edge provenance, like the source this relationship came from and the method used to make this association, to filter out edges (removing nodes in the process). Before filtering, we have a large number of results (see output from code block above) and paths between the SARS node and Gene nodes (see output from code block below).
#
# Note that there is no method information in this particular table to filter on.

# %%
## show number of paths from SARS to genes
print("There are {0} unique paths.".format( \
    q2_r_paths_table.shape[0]))

## show that there isn't any method information in this table
## shows number of cells without missing data (aka non-NA values)
print("\nThere is no method information in this table.")
q2_r_paths_table[['pred1_method', 'pred2_method']].count()
# Out:
# There are 58774 unique paths.
#
# There is no method information in this table.
# pred1_method    0
# pred2_method    0
# dtype: int64

# %%
q2_r_paths_table = filter_table(q2_r_paths_table)

# %% [markdown]
# After filtering, there are fewer paths (and fewer nodes/edges) in the answer knowledge graph.

# %%
## show number of unique intermediate nodes
print("There are {0} unique {1}s for {2}.".format( \
    q2_r_paths_table.node1_name.nunique(), q2_intermediate, corona_starting_str))

## show number of unique output nodes
print("There are {0} unique Genes linked to those {1}s.".format( \
    q2_r_paths_table.output_name.nunique(), q2_intermediate))

## show number of paths from SARS to genes
print("There are {0} unique paths.".format( \
    q2_r_paths_table.shape[0]))

# %% [markdown]
# The scoring process relies on the assumption that the user would be most interested in Genes that share many ChemicalSubstances (intermediate nodes) with SARS.
#
# To score individual Gene nodes, we first take a copy of the knowledge graph (KG) and flatten the multi-edges into single edges.
#
# We then count the number of paths from the SARS node to each Gene node. This count is also equivalent to the number of ChemicalSubstances that SARS and the Gene in common and to the node (out)degree of the Gene in the flattened KG.
#
# Finally, we "normalize" the score by dividing those counts by maximum-possible number of paths from the SARS node to a Gene node. In this case (with one input node and one intermediate node type), this is equivalent to the number of ChemicalSubstances nodes.
#
# We can then see the top-scored nodes. A score of 1 would mean that the maximum number of ChemicalSubstances were linked to both SARS and to that Gene. A score closer to 0 would mean that only a few ChemicalSubstances were linked to both SARS and to that Gene.

# %%
## create scoring table for Genes (output nodes)
q2_scoring = scoring_output(q2_r_paths_table, q2_type)

q2_scoring.head(10)
# Out:
#            score
# PPIB    0.366667
# CAT     0.333333
# CASP14  0.266667
# TLN1    0.266667
# DUOXA1  0.233333
# INS     0.233333
# IDS     0.200000
# 7841    0.200000
# BCAT2   0.200000
# PTS     0.200000

# %% [markdown]
# [TO DO: Actual code depends on graph object (ReasonerStd object or Networkx MultiDiGraph) used.]
#
# We then add the scores and score provenance information to the graph object that will be returned to the ARS. These stored as node attributes on the Gene nodes of the "answer graph".

# %%
# nx.set_node_attributes(q2_r_graph, values = q2_scoring.to_dict(), \
#                        name = 'score')
# nx.set_node_attributes(q2_r_graph, values = '(0-1]', name = 'score_range')
# nx.set_node_attributes(q2_r_graph, values = 'normalized path count', name = 'score_method')
# ## what is a good score, larger or smaller? 
# nx.set_node_attributes(q2_r_graph, values = 'larger', name = 'score_better_direction')  

# ## example of Gene node object with score-related attributes
# q2_r_graph.nodes()['BCAT2']
